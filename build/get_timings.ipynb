# %%
'''
from subprocess import call
import csv
import os

#compressed_name = "dnb_set=authorities_partition=werk_compressed"


date = "06_06_2024"
num_node_labels = 1000
num_edge_labels = 4
num_edges = 1000
str_len = 4

while str_len <= 64:

    path_og = "/home/dtkhuat/results/random_graphs/var_edge_len/"+ str(str_len) + "/"
    path_incidence =  "/home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_edge_len/"+str(str_len)+"/"
    path_index = "/home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_edge_len/"+str(str_len)+"/"
    call(["mkdir",path_incidence])
    call(["mkdir",path_index])
    call(["touch",path_og+date+".csv"])

    
    
    
    for i in range(100):
        file_name = "random_"+str(num_node_labels)+"_4_"+str(num_edges)+"_"
        compressed_name = file_name + str(i) + "_c"
        call(["/home/dtkhuat/IncidenceTypeRePair/build/./cgraph-cli", "--overwrite", "--rrr", "--verbose", path_og + file_name + str(i)+".ttl",  path_incidence+compressed_name])
        call(["./cgraph-cli", "--overwrite", "--rrr", "--verbose",path_og + file_name + str(i)+".ttl", path_index + compressed_name])


        
        with open(path_og+date+'.csv', 'a') as csv_file:
            fields = [file_name+ str(i)+".ttl", os.stat(path_og + file_name+ str(i)+".ttl").st_size, os.stat(path_incidence+compressed_name).st_size, os.stat(path_index+compressed_name).st_size]
            csv_writer = csv.writer(csv_file, delimiter=',')
            csv_writer.writerow(fields)
        
        if(i<99):
            with open('/home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_edge_len/timings.csv', 'a') as csv_file:
               #csv_writer = csv.writer(csv_file, delimiter=',')
                csv_file.write(", ")
                csv_file.close()
            with open('/home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_edge_len/timings.csv', 'a') as csv_file:
                #csv_writer = csv.writer(csv_file, delimiter=',')
                csv_file.write(", ")
                csv_file.close()
        else:
            with open('/home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_edge_len/timings.csv', 'a') as csv_file:
                csv_file.write("\n")
                csv_file.close()
            with open('/home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_edge_len/timings.csv', 'a') as csv_file:
                csv_file.write("\n")
                csv_file.close()

    str_len = str_len + 4
'''

from subprocess import call
import csv
import os

#compressed_name = "dnb_set=authorities_partition=werk_compressed"


date = "23_07_2024"
num_node_labels = 1000
num_edge_labels = 4
num_edges = 1000
str_len = 4
increment = 4

researched_path = "var_num_edge_labels3/"
while num_edge_labels <= 64:
    researched = str(num_edge_labels)
    path_og = "/home/dtkhuat/results/random_graphs/"+ researched_path+ researched + "/"
    path_incidence =  "/home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/"+ researched_path+researched+"/"
    path_index = "/home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/"+ researched_path+researched+"/"
    call(["mkdir",path_incidence])
    call(["mkdir",path_index])
    call(["touch",path_og+date+".csv"])

    
    
    
    for i in range(100):
        file_name = "random_"+str(num_node_labels)+"_"+researched +"_"+str(num_edges)+"_"
        compressed_name = file_name + str(i) + "_c"
        #WRITE TIMINGS
        #call(["/home/dtkhuat/IncidenceTypeRePair/build/./cgraph-cli", "--overwrite", "--rrr", "--verbose", path_og + file_name + str(i)+".ttl",  path_incidence+compressed_name])
        #call(["./cgraph-cli", "--overwrite", "--rrr", "--verbose",path_og + file_name + str(i)+".ttl", path_index + compressed_name])
        call(["/home/dtkhuat/IncidenceTypeRePair/build/./cgraph-cli", "--overwrite", "--rrr", "--verbose","--factor", "8", "--sampling", "32", "--max-rank","12", path_og + file_name + str(i)+".ttl",  path_incidence+compressed_name])
        call(["./cgraph-cli", "--overwrite", "--rrr", "--verbose", "--factor", "8", "--sampling", "32", "--max-rank","12" ,path_og + file_name + str(i)+".ttl", path_index + compressed_name])

        #WRITE DATA SIZE
        with open(path_og+date+'.csv', 'a') as csv_file:
            fields = [file_name+ str(i)+".ttl", os.stat(path_og + file_name+ str(i)+".ttl").st_size, os.stat(path_incidence+compressed_name).st_size, os.stat(path_index+compressed_name).st_size]
            csv_writer = csv.writer(csv_file, delimiter=',')
            csv_writer.writerow(fields)
        
        
        if(i<99):
            with open('/home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/'+researched_path+'timings_'+date + '.csv', 'a') as csv_file:
               #csv_writer = csv.writer(csv_file, delimiter=',')
                csv_file.write(", ")
                csv_file.close()
            with open('/home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/'+researched_path+'timings_'+date + '.csv', 'a') as csv_file:
                #csv_writer = csv.writer(csv_file, delimiter=',')
                csv_file.write(", ")
                csv_file.close()
        else:
            with open('/home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/'+researched_path+'timings_'+date + '.csv', 'a') as csv_file:
                csv_file.write("\n")
                csv_file.close()
            with open('/home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/'+researched_path+'timings_'+date + '.csv', 'a') as csv_file:
                csv_file.write("\n")
                csv_file.close()

    num_edge_labels = num_edge_labels + increment
# Out:
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_0.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_0_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4379 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_0.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_0_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7192 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_1.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_1_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4385 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_1.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_1_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7086 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_2.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_2_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4418 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_2.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_2_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7078 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_3.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_3_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4390 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_3.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_3_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7100 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_4.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_4_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4406 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_4.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_4_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7116 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_5.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_5_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4407 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_5.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_5_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7111 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_6.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_6_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4376 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_6.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_6_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7087 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_7.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_7_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4357 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_7.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_7_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7133 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_8.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_8_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4437 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_8.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_8_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7229 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_9.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_9_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4402 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_9.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_9_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7120 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_10.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4409 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_10.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7218 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_11.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_11_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4394 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_11.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_11_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7209 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_12.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_12_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4385 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_12.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_12_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7215 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_13.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_13_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4260 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_13.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_13_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7124 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_14.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_14_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4395 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_14.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_14_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7199 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_15.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_15_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4291 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_15.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_15_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7082 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_16.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_16_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4247 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_16.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_16_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7097 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_17.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_17_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4443 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_17.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_17_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7232 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_18.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_18_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4360 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_18.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_18_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7100 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_19.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_19_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4315 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_19.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_19_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7051 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_20.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_20_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4406 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_20.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_20_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7187 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_21.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_21_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4355 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_21.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_21_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7057 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_22.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_22_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4269 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_22.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_22_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7141 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_23.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_23_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4431 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_23.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_23_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7187 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_24.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_24_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4373 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_24.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_24_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7163 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_25.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_25_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4258 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_25.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_25_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7088 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_26.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_26_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4371 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_26.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_26_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7127 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_27.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_27_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4307 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_27.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_27_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7206 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_28.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_28_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4371 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_28.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_28_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7202 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_29.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_29_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4372 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_29.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_29_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7164 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_30.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_30_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4289 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_30.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_30_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7127 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_31.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_31_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4310 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_31.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_31_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7160 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_32.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_32_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4359 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_32.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_32_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7119 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_33.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_33_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4373 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_33.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_33_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7190 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_34.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_34_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4332 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_34.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_34_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7126 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_35.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_35_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4388 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_35.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_35_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7128 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_36.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000_36_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 4271 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_36.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/4/random_1000_4_1000_36_c
#   Writing magic
#   Writing meta
#   Writing grammar
#   Grammar Size is 7173 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 12
# - monograms: false
# - factor: 8
# - sampling: 32
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_edge_labels3/4/random_1000_4_1000_37.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/4/random_1000_4_1000