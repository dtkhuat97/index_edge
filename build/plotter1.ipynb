# %%
#PLOT

# %%
pip install matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.5/159.5 kB 687.8 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 361.8 kB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.0/306.0 kB 250.1 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 375.3 kB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 481.1 kB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 410.2 kB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 369.8 kB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from subprocess import call
import csv
import os
import numpy as np
import matplotlib.pyplot as plt
import statistics

# %%
path = "/home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edges/"
timings = []
with open(path+'timings.csv', 'r') as csv_file:
    csvreader = csv.reader(csv_file, quoting=csv.QUOTE_NONNUMERIC)
    for row in csvreader:
        timings.append(row)

print(np.asarray(timings).shape)
fig = plt.figure(figsize =(5, 3))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("Number of Edges")
plt.ylabel("Compression time in seconds")
#bp = ax.stem(timings,showfliers=False,showmeans=True)
x_error = []
y_error = []
x = []
y = []
for i in range(0,10):
    y.append(statistics.mean(timings[i]))
    x.append((i+1)*1000)
    x_error.append(max(timings[i])-y[i])
    y_error.append(y[i]-min(timings[i]))
#bp = ax.errorbar(x, y, yerr = y_error,xerr = x_error, fmt='o', linewidth=2, capsize= 6,label="ITR on RDF Graphs")
plt.plot(x, y, linestyle='-', marker='o', label="ITR on RDF Graphs")


path = "/home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edges/"
timings = []
with open(path+'timings.csv', 'r') as csv_file:
    csvreader = csv.reader(csv_file, quoting=csv.QUOTE_NONNUMERIC)
    for row in csvreader:
        timings.append(row)

#bp = ax.stem(timings,showfliers=False,showmeans=True)
x_error = []
y_error = []
x = []
y = []
for i in range(0,10):
    y.append(statistics.mean(timings[i]))
    x.append((i+1)*1000)
    x_error.append(max(timings[i])-y[i])
    y_error.append(y[i]-min(timings[i]))
#bp = ax.errorbar(x, y, yerr = y_error,xerr = x_error, fmt='o', linewidth=2, capsize=6, label="ITR on Graphs with indexed Edges")
plt.plot(x, y, linestyle='-', marker='o',label="ITR on Graphs with indexed Edges")
plt.legend(loc="upper left")
plt.xticks(np.arange(0, 10001,  step=1000))
plt.yticks(np.arange(0, 0.21, step=0.02))
plt.savefig("/home/dtkhuat/plots/test/timing_var_num_edges.pdf", format="pdf", bbox_inches="tight")
plt.show()
plt.close()
# Out:
# (10, 100)

# %%
path = "/home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edges/"
timings = []
with open(path+'timings.csv', 'r') as csv_file:
    csvreader = csv.reader(csv_file, quoting=csv.QUOTE_NONNUMERIC)
    for row in csvreader:
        timings.append(row)

print(np.asarray(timings).shape)
fig = plt.figure(figsize =(5, 5))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("Number of Edges")
plt.ylabel("Compression time in seconds")
#bp = ax.stem(timings,showfliers=False,showmeans=True)
x_error = []
y_error = []
x = []
y = []
for i in range(0,10):
    y.append(statistics.mean(timings[i]))
    x.append((i+1)*1000)
    x_error.append(max(timings[i])-y[i])
    y_error.append(y[i]-min(timings[i]))
bp = ax.errorbar(x, y, yerr = y_error,xerr = x_error, fmt='o', linewidth=2, capsize=6)
plt.savefig("/home/dtkhuat/plots/IE_var_num_edges.pdf", format="pdf", bbox_inches="tight")
# Out:
# (10, 100)

# %% [markdown]
# ##PLOT TIMING VAR EDGE LEN

# %%
path = "/home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_edge_len/"
timings = []
date = '06_06_2024'
with open(path+'timings'+date+'.csv', 'r') as csv_file:
    csvreader = csv.reader(csv_file, quoting=csv.QUOTE_NONNUMERIC)
    for row in csvreader:
        timings.append(row)

print(np.asarray(timings).shape)
fig = plt.figure(figsize =(5, 3))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("Maximum Length of Node and Edge Labels")
plt.ylabel("Compression time in seconds")
#bp = ax.stem(timings,showfliers=False,showmeans=True)
x_error = []
y_error = []
x = []
y = []
for i in range(0,16):
    y.append(statistics.mean(timings[i]))
    x.append((i+1)*4)
    x_error.append(max(timings[i])-y[i])
    y_error.append(y[i]-min(timings[i]))
#plt.axis([0, 70, 0, 0.01])
#bp = ax.errorbar(x, y, yerr = y_error,xerr = x_error, fmt='o', linewidth=2, capsize=6)
plt.plot(x,y , linestyle='-', marker='o', label ="ITR on RDF Graphs")
path = "/home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_edge_len/"
timings = []
date = '06_06_2024'
with open(path+'timings'+date+'.csv', 'r') as csv_file:
    csvreader = csv.reader(csv_file, quoting=csv.QUOTE_NONNUMERIC)
    for row in csvreader:
        timings.append(row)

#bp = ax.stem(timings,showfliers=False,showmeans=True)
x_error = []
y_error = []
x = []
y = []
for i in range(0,16):
    y.append(statistics.mean(timings[i]))
    x.append((i+1)*4)
    x_error.append(max(timings[i])-y[i])
    y_error.append(y[i]-min(timings[i]))
#plt.axis([0, 12000, 0, 0.01])
#bp = ax.errorbar(x, y, yerr = y_error,xerr = x_error, fmt='o', linewidth=2, capsize=6)
plt.plot(x,y , linestyle='-', marker='o',label="ITR on Graphs with indexed Edges")
plt.legend(loc="upper left")
plt.xticks(np.arange(0, 65,  step=4))
plt.yticks(np.arange(0, 0.021, step=0.002))
plt.savefig("/home/dtkhuat/plots/test/timing_var_edge_len3.pdf", format="pdf", bbox_inches="tight")
# Out:
# (16, 100)

# %% [markdown]
# ##GET TIMING NUM NODES

# %%
path = "/home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_nodes/"
timings = []
date = '06_06_2024'
with open(path+'timings'+date+'.csv', 'r') as csv_file:
    csvreader = csv.reader(csv_file, quoting=csv.QUOTE_NONNUMERIC)
    for row in csvreader:
        timings.append(row)

print(np.asarray(timings).shape)
fig = plt.figure(figsize =(5, 3))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("Number of Nodes")
plt.ylabel("Compression time in seconds")
#bp = ax.stem(timings,showfliers=False,showmeans=True)
x_error = []
y_error = []
x = []
y = []
for i in range(0,10):
    y.append(statistics.mean(timings[i]))
    x.append((i+1)*1000)
    x_error.append(max(timings[i])-y[i])
    y_error.append(y[i]-min(timings[i]))
#plt.axis([0, 12000, 0, 0.01])
#bp = ax.errorbar(x, y, yerr = y_error,xerr = x_error, fmt='o', linewidth=2, capsize=6)
plt.plot(x,y, linestyle='-', marker='o', label = "ITR on RDF Graphs")

path = "/home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_nodes/"
timings = []
date = '06_06_2024'
with open(path+'timings'+date+'.csv', 'r') as csv_file:
    csvreader = csv.reader(csv_file, quoting=csv.QUOTE_NONNUMERIC)
    for row in csvreader:
        timings.append(row)

x_error = []
y_error = []
x = []
y = []
for i in range(0,10):
    y.append(statistics.mean(timings[i]))
    x.append((i+1)*1000)
    x_error.append(max(timings[i])-y[i])
    y_error.append(y[i]-min(timings[i]))
plt.plot(x,y, linestyle='-', marker='o', label = "ITR on Graphs with indexed Edges")
plt.xticks(np.arange(0, 10001,  step=1000))
plt.yticks(np.arange(0, 0.021, step=0.002))
plt.legend(loc="upper left")
plt.savefig("/home/dtkhuat/plots/test/timing_var_num_nodes.pdf", format="pdf", bbox_inches="tight")
# Out:
# (10, 100)

# %% [markdown]
# ##GET TIMING NUM EDGE LABELS

# %%
path = "/home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_num_edge_labels3/"
timings = []
#date = '03_06_2024'
date = "23_07_2024"
with open(path+'timings_'+date+'.csv', 'r') as csv_file:
    csvreader = csv.reader(csv_file, quoting=csv.QUOTE_NONNUMERIC)
    for row in csvreader:
        timings.append(row)

print(np.asarray(timings).shape)
fig = plt.figure(figsize =(5, 3))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("Number of Edge Labels")
plt.ylabel("Compression time in seconds")
#bp = ax.stem(timings,showfliers=False,showmeans=True)
x_error = []
y_error = []
x = []
y = []
print()
for i in range(0,10):
    y.append(statistics.mean(timings[i]))
    x.append((i+1)*4)
    x_error.append(max(timings[i])-y[i])
    y_error.append(y[i]-min(timings[i]))
#plt.axis([0, 12000, 0, 0.01])
#bp = ax.errorbar(x, y, yerr = y_error,xerr = x_error, fmt='o', linewidth=2, capsize=6)
plt.plot(x,y,linestyle='-', marker='o' , label = "ITR on RDF Graphs")

path = "/home/dtkhuat/results/random_graphs_compressed/IndexedEdges_compressed/var_num_edge_labels3/"
timings = []
#date = '03_06_2024'
date = "23_07_2024"
with open(path+'timings_'+date+'.csv', 'r') as csv_file:
    csvreader = csv.reader(csv_file, quoting=csv.QUOTE_NONNUMERIC)
    for row in csvreader:
        timings.append(row)

x_error = []
y_error = []
x = []
y = []
for i in range(0,10):
    y.append(statistics.mean(timings[i]))
    x.append((i+1)*4)
    x_error.append(max(timings[i])-y[i])
    y_error.append(y[i]-min(timings[i]))
print(x,y)
plt.plot(x,y,linestyle='-', marker='o' , label = "ITR on Graphs with indexed Edges")
plt.xticks(np.arange(0,41, step=4))
plt.yticks(np.arange(0, 0.021, step=0.002))

plt.legend(loc="upper right")
#plt.savefig("/home/dtkhuat/plots/test/timing_var_num_edge_labels"+date+".pdf", format="pdf", bbox_inches="tight")
#plt.savefig("/home/dtkhuat/plots/test/timing_var_num_edge_labels2.pdf", format="pdf", bbox_inches="tight")
# Out:
# (16, 100)
#
# [4, 8, 12, 16, 20, 24, 28, 32, 36, 40] [0.00901033, 0.00881544, 0.00830291, 0.00753213, 0.00664826, 0.00564042, 0.00466925, 0.00413419, 0.00374143, 0.00357332]

# %%
#path = "/home/dtkhuat/results/sizes/"
path = "/home/dtkhuat/index_values/timing/"
#date = '03_06_2024'
#date = "24_07_2024"
date =  "semi_real_23_07_2024.csv"
ir_c = []
ie_c = []
label = []
y = []
#'21_04_24.csv'
#date = "18_07_2024.csv"
with open(path+date, 'r') as csv_file:
    csvreader = csv.reader(csv_file)
    #next(csvreader, None) 
    for row in csvreader:
        label.append(row[0])
        #original.append(float(row[1]))
        ir_c.append(float(row[1]))
        ie_c.append(float(row[2]))

#label=label[:-1]
print(ir_c)
fig = plt.figure(figsize =(5, 3))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("File Name")
plt.ylabel("Compression time in seconds")
x = np.arange(0,30,step=5)
for i in range(0, len(x)):
    x[i] = x[i]-1
#bp = ax.bar(x, ir_c, width = 2, label = "ITR on RDF Graphs")
plt.plot(x,ir_c,linestyle='-', marker='o' , label = "ITR on RDF Graphs")
plt.plot(x,ie_c,linestyle='-', marker='o' , label = "ITR on Graphs with indexed Edges")
label = ['export','homepages-en','taxonomy', 'long-abstracts', 'jamendo', 'scholarydata-dump', 'bag-transformed','lubm-10','archiveshub','geo-coordinates-en', 'ontology']
ax.set_xticks(x, labels=label)
#plt.xticks(x,rotation=90)
plt.xticks(x,rotation=45, ha = "right")
plt.yticks(np.arange(0, 300, step = 25))
plt.legend(loc="upper left")
plt.savefig("/home/dtkhuat/plots/test/timing_real_24_07_2024.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
'''
path = "/home/dtkhuat/index_values/timing/"
timings = []
#date = '03_06_2024'
#date = "24_07_2024"
date =  "real_18_07_2024.csv"
label = []
y_itr = []
y_index = []
x = np.arange(1,12,step=1)
with open(path+date, 'r') as csv_file:
    csvreader = csv.reader(csv_file)
    #next(csvreader, None) 
    for row in csvreader:
        label.append(row[0])
        y_itr.append(row[1])
        y_index.append(row[2])


fig = plt.figure(figsize =(5, 5))
ax = fig.add_axes([0, 0, 1, 1])

#plt.plot(x,y_itr,linestyle='-', marker='o' , label = "ITR on RDF Graphs")
plt.xlabel("File Name")
plt.ylabel("Compression time in seconds")
#bp = ax.stem(timings,showfliers=False,showmeans=True)

print(x,y_itr)
plt.plot(x[0:3],y_itr[0:3],linestyle='-', marker='o' , label = "ITR on RDF Graphs")
#plt.plot(x,y_index,linestyle='-', marker='o' , label = "ITR on Graphs with indexed Edges")
ax.set_xticks(x, labels=label)
plt.xticks(x,rotation=45, ha = "right")
plt.yticks(np.arange(0, 120, step = 10))
plt.show()
plt.savefig("/home/dtkhuat/plots/test/timing_real.pdf", format="pdf", bbox_inches="tight")
'''



#path = "/home/dtkhuat/results/sizes/"
path = "/home/dtkhuat/index_values/timing/"
#date = '03_06_2024'
#date = "24_07_2024"
date =  "real_23_07_2024.csv"
ir_c = []
ie_c = []
label = []
y = []
#'21_04_24.csv'
#date = "18_07_2024.csv"
with open(path+date, 'r') as csv_file:
    csvreader = csv.reader(csv_file)
    #next(csvreader, None) 
    for row in csvreader:
        label.append(row[0])
        #original.append(float(row[1]))
        ir_c.append(float(row[1]))
        ie_c.append(float(row[2]))

#label=label[:-1]
print(ir_c)
fig = plt.figure(figsize =(5, 2.5))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("File Name")
plt.ylabel("Compression time in seconds")
x = np.arange(0,51,step=5)
for i in range(0, len(x)):
    x[i] = x[i]-1
#bp = ax.bar(x, ir_c, width = 2, label = "ITR on RDF Graphs")
plt.plot(x,ir_c,linestyle='-', marker='o' , label = "ITR on RDF Graphs")
plt.plot(x,ie_c,linestyle='-', marker='o' , label = "ITR on Graphs with indexed Edges")
label = ['export','homepages-en','taxonomy', 'long-abstracts', 'jamendo', 'scholarydata-dump', 'bag-transformed','lubm-10','archiveshub','geo-coordinates-en', 'ontology']
ax.set_xticks(x, labels=label)
#plt.xticks(x,rotation=90)
#plt.xticks(x,rotation=45, ha = "right")
plt.xticks(x,rotation=15, ha = "right")
plt.yticks(np.arange(0, 300, step = 25))
plt.legend(loc="upper left")
#plt.savefig("/home/dtkhuat/plots/test/timing_real_24_07_2024.pdf", format="pdf", bbox_inches="tight")
plt.savefig("/home/dtkhuat/plots/test/replace_real_index_time3.pdf", format="pdf", bbox_inches="tight")
plt.show()
# Out:
# [0.364601, 0.409491, 1.248581, 5.845934, 31.354031, 25.273211, 18.026171, 26.20036, 61.545245, 76.953355, 179.810526]
